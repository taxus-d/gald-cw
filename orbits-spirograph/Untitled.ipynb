# %%
t = var('t')
w1, w0 = var('w1, w0')

# %%
solve(diff(cos(w1*t)*cos(w0*t) + sin(w1*t)*sin(w0*t), t) == 0, t)
# Out:
# [sin(t*w1) == cos(t*w1)*sin(t*w0)/cos(t*w0)]

# %%
plot([tan(1*x), tan(0.4*x)], (x, -5, 5), ymax=10, ymin=-10)
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
plot([0.33*cos(1*x)^2, 1*cos(0.333*x)^2], (x, -5, 5))
# Out:
# Graphics object consisting of 2 graphics primitives
